# %% [markdown]
# # Creation of in vitro insertion parts for pfa chain in C.Cinerea

# %% [markdown]
# Now that promoters have been collected and generated and ran through a quantative flouresence analysis we can create the full list of inserts and necesarry primers for the top 5 primers and terminators.
#
# This insert will contain: <br>
# - PABA marker gene <br>
# - PUFA synthesis pathway <br>
#     - pfa1,2,3 and a pptase <br>
# - Hygromicin marker gene.

# %% [markdown]
# *this is where we insert a cool image of the creation*

# %% [markdown]
# ## Loading Libraries

# %%
from teemi.design.combinatorial_design import DesignAssembly
import os
from IPython.display import display

os.chdir("..") #move to root to allow relative import
from src.smart_functions import read_fasta_to_dseqrecords

# %% [markdown]
# ## Genetic elements

# %% [markdown]
# ### Homologous recombination PABA marker

# %% [markdown]
# The PABA marker contains a homologous arm to restore PABA auxotrophy by introducing a amino acid change from glutamic acid to arginine. Correct homologous recombination can then be achieved and validated with diagnostic PCR.

# %% [markdown]
# ### PUFA Synthesis pathway

# %% [markdown]
# The PUFA synthesis pathway is from *Aetherobacter fasciculatus* (SBSr002) and contains pfa1, pfa2, pfa3 and a pptase for DHA synthesis

# %% [markdown]
# ## Primer creation using TEEMI

# %% [markdown]
# ### Fetching everything

# %%
top_promoters = r'data/promoter_terminator_library/subset_promoter.fasta'
top_terminators = r'data/promoter_terminator_library/subset_terminator.fasta'

m_paba_fa = r'data/insert_sequences/PABA.fasta'
cds_fa = r'data/insert_sequences/pufa_optimized.fasta' #pfa123 and pptase

promoters, promoter_names = read_fasta_to_dseqrecords(top_promoters)
terminators, terminator_names = read_fasta_to_dseqrecords(top_terminators)

cds_records, cds_names = read_fasta_to_dseqrecords(cds_fa)
m_paba, m_paba_names = read_fasta_to_dseqrecords(m_paba_fa)

# %% [markdown]
# #### A quick count of sequences

# %%
print(f"Promoters: {len(promoters)}, CDS: {len(cds_records)}, Terminators: {len(terminators)}")
# Out:
# Promoters: 4, CDS: 4, Terminators: 3

# %% [markdown]
# ### Putting it all together in a list for DesignAssembly

# %%
list_of_seqs  = [[m_paba[0]], 
                 promoters, [cds_records[0]], terminators, 
                 promoters, [cds_records[1]], terminators, 
                 promoters, [cds_records[2]], terminators,
                 promoters, [cds_records[3]], terminators,
                 [m_paba[1]], 
                 ]

# %% [markdown]
# ### DesignAssembly

# %%
TARGET_TM = 65
LIMIT = 28
OVERLAP = 35


design = DesignAssembly(list_of_seqs, list_of_pads=[], positions_of_pads=[], target_tm=TARGET_TM, limit=LIMIT, overlap=OVERLAP)
variants_df = design.show_variants_lib_df()          
primers_df  = design.primer_list_to_dataframe()      
pcrs_df = design.pcr_list_to_dataframe()


out_dir = os.getcwd()
variants_csv = os.path.join(out_dir, "data/constructs/full_construct_variants_library.csv")
primers_csv  = os.path.join(out_dir, "data/constructs/full_construct_primers_list.csv")
pcrs_csv= os.path.join(out_dir, "data/constructs/full_construct_pcr_plan.csv")

variants_df.to_csv(variants_csv, index=False)
primers_df.to_csv(primers_csv, index=False)
pcrs_df.to_csv(pcrs_csv, index=False)

print(f"Variants: {len(variants_df)}")
print(f"Primers:  {len(primers_df)}")
print(f"PCRs:     {len(pcrs_df)}")
display(variants_df.head())
display(primers_df.head())
display(pcrs_df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       2 LIMIT = 28
#       3 OVERLAP = 35
# ----> 6 design = DesignAssembly(list_of_seqs, list_of_pads=[], positions_of_pads=[], target_tm=TARGET_TM, limit=LIMIT, overlap=OVERLAP)
#       7 variants_df = design.show_variants_lib_df()
#       8 primers_df  = design.primer_list_to_dataframe()
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\teemi\design\combinatorial_design.py:115, in DesignAssembly.__init__(self, list_of_seqs, list_of_pads, positions_of_pads, target_tm, limit, overlap, tm_func)
#     112         self.combinatorial_list_of_amplicons[i].insert(pos, pads)
#     114 ### 5. Assembling and making overlapping primers
# --> 115 self.list_of_assemblies = assembly_maker(
#     116     self.combinatorial_list_of_amplicons, overlap=overlap
#     117 )
#     119 ### 6. GETTING all primers, annotating, adding features
#     120 self.primers = get_primers(
#     121     self.list_of_assemblies,
#     122     self.combinatorial_list_of_names,
#     123     self.combinatorial_list_of_primer_tm,
#     124 )
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\teemi\design\combinatorial_design.py:407, in assembly_maker(combinatorial_list_of_amplicons, overlap)
#     404 list_of_assemblies = []
#     405 for i in range(0, len(combinatorial_list_of_amplicons)):
#     406     list_of_assemblies.append(
# --> 407         assembly_fragments(combinatorial_list_of_amplicons[i], overlap, maxlink=40)
#     408     )
#     410 return list_of_assemblies
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydna\design.py:780, in assembly_fragments(f, overlap, maxlink, circular)
#     776 # _module_logger.debug("loop ended")
#     778 f = [item for item in f if len(item)]
# --> 780 return [
#     781     (
#     782         _pcr(
#     783             p.forward_primer,
#     784             p.reverse_primer,
#     785             p.template,
#     786             limit=min((p.forward_primer._fp, p.reverse_primer._fp)),
#     787         )
#     788         if hasattr(p, "template")
#     789         else p
#     790     )
#     791     for p in f
#     792 ]
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydna\design.py:782, in <listcomp>(.0)
#     776 # _module_logger.debug("loop ended")
#     778 f = [item for item in f if len(item)]
#     780 return [
#     781     (
# --> 782         _pcr(
#     783             p.forward_primer,
#     784             p.reverse_primer,
#     785             p.template,
#     786             limit=min((p.forward_primer._fp, p.reverse_primer._fp)),
#     787         )
#     788         if hasattr(p, "template")
#     789         else p
#     790     )
#     791     for p in f
#     792 ]
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydna\amplify.py:551, in pcr(*args, **kwargs)
#     548 if not hasattr(new[-1].seq, "watson"):
#     549     new[-1] = _Dseqrecord(s)
# --> 551 anneal_primers = Anneal(new[:-1], new[-1], **kwargs)
#     553 if len(anneal_primers.products) == 1:
#     554     return anneal_primers.products[0]
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydna\amplify.py:255, in Anneal.__init__(self, primers, template, limit, **kwargs)
#     242 for p in self.primers:
#     243     self.forward_primers.extend(
#     244         (
#     245             _Primer(
#    (...)
#     253         )
#     254     )
# --> 255     self.reverse_primers.extend(
#     256         (
#     257             _Primer(
#     258                 p,
#     259                 #          template = self.template,
#     260                 position=pos + max(0, self.template.seq.ovhg),
#     261                 footprint=fp,
#     262             )
#     263             for pos, fp in _annealing_positions(str(p.seq), tw, self.limit)
#     264             if pos < twl
#     265         )
#     266     )
#     268 self.forward_primers.sort(key=_operator.attrgetter("position"))
#     269 self.reverse_primers.sort(key=_operator.attrgetter("position"), reverse=True)
#
# KeyboardInterrupt:
